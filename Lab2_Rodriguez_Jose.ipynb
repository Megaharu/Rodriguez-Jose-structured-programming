# %% [markdown]
# <a href="https://colab.research.google.com/github/Megaharu/Rodriguez-Jose-structured-programming/blob/main/Lab2_Rodriguez_Jose.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Code A

# %%
def multiply(a, b):
    return a * b
print(multiply(3, 4))
# Out:
# 12

# %% [markdown]
# Code B

# %%
counter = 0
for i in range(4):
    counter= counter + 1
print(counter)
# Out:
# 4

# %% [markdown]
# Code C

# %%
a = 3
b = 4
temp = a
a = b
b = temp
print(a)
print(b)
# Out:
# 4
# 3

# %% [markdown]
# Modified Code

# %%
a = 10
b = 20
temp = a
a = b
b = temp
print(a)
print(b)
# Out:
# 20
# 10
